# %%
class Employee:
    name = 'Love singh'
    Salary = 10000
objEmployee = Employee()
print('Name of employee = ', objEmployee.name , ', Salary of employee = ', objEmployee.Salary)
# Out:
# Name of employee =  Love singh , Salary of employee =  10000
# Area =  30

# %%
# Normal class with function
class Room:
    lenght = 0
    breadth = 0
    
    # Area calculation function
    def area(self):
        result = self.lenght * self.breadth
        print('Area = ', result)

objRoom = Room()
objRoom.lenght = 5
objRoom.breadth = 6
objRoom.area()
# Out:
# Area =  30

# %%
# program of constructor
class House:
